# %%
from dataset import sample
from train import *
from get_example_spectrum import get_example_spectrum
from predict import predict

# %%
sample()

# %%
train_randomforest()  # Change here based on functions in train.py
# Out:
# MAE: B, theta, phi: [5.87138731 0.82608936 1.68552551]

# %%
get_example_spectrum()
# Out:
# Saved 5 example spectra from first keys: ['{100.645, 0.304242, 5.5785}', '{100.813, 1.76397, 3.25462}', '{101.417, 2.44469, 4.78751}', '{101.431, 0.970714, 4.50923}', '{101.439, 0.204534, 3.98642}'] shapes [(2761, 2), (2766, 2), (2782, 2), (2783, 2), (2783, 2)]

# %%
predict("data/example_spectrum.npy")
